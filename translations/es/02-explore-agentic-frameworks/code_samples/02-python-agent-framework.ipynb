# %% [markdown]
# # 🔍 Explorando Marcos Agénticos - Agente Básico (Python)
#
# ## 📋 Objetivos de Aprendizaje
#
# Este cuaderno explora los conceptos fundamentales del Marco de Agentes de Microsoft a través de una implementación básica de un agente. Aprenderás patrones agénticos esenciales y comprenderás cómo funcionan los agentes inteligentes en su núcleo.
#
# **Lo que descubrirás:**
# - 🏗️ **Arquitectura de Agentes**: Comprender la estructura básica de los agentes de IA
# - 🛠️ **Integración de Herramientas**: Cómo los agentes utilizan funciones externas para ampliar sus capacidades
# - 💬 **Flujo de Conversación**: Gestión de conversaciones de múltiples turnos y contexto
# - 🔧 **Patrones de Configuración**: Mejores prácticas para la configuración y gestión de agentes
#
# ## 🎯 Conceptos Clave Cubiertos
#
# ### Principios del Marco Agéntico
# - **Autonomía**: Cómo los agentes toman decisiones independientes
# - **Reactividad**: Responder a cambios en el entorno y entradas del usuario
# - **Proactividad**: Tomar la iniciativa basada en objetivos y contexto
# - **Habilidad Social**: Interactuar mediante lenguaje natural
#
# ### Componentes Técnicos
# - **ChatAgent**: Orquestación central del agente y gestión de conversaciones
# - **Funciones de Herramientas**: Ampliar las capacidades del agente con funciones personalizadas
# - **Integración con OpenAI**: Aprovechar modelos de lenguaje a través de APIs estandarizadas
# - **Gestión del Entorno**: Configuración segura y manejo de credenciales
#
# ## ⚙️ Requisitos Previos y Configuración
#
# **Dependencias Requeridas:**
# ```bash
#
# pip install agent-framework-core  -U
# ```
#
# **Configuración del Entorno (archivo .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🔧 Stack Técnico
#
# **Tecnologías Principales:**
# - Marco de Agentes de Microsoft (Python)
# - Integración con API de Modelos de GitHub
# - Patrones de cliente compatibles con OpenAI
# - Configuración basada en entorno
#
# **Capacidades del Agente:**
# - Comprensión y generación de lenguaje natural
# - Llamadas a funciones y uso de herramientas
# - Respuestas conscientes del contexto
# - Arquitectura extensible
#
# ## 📚 Comparación de Marcos
#
# Este ejemplo demuestra el enfoque del Marco de Agentes de Microsoft en comparación con otros marcos agénticos:
#
# | Característica | Marco de Agentes de Microsoft | Otros Marcos |
# |----------------|-------------------------------|--------------|
# | **Integración** | Ecosistema nativo de Microsoft | Compatibilidad variada |
# | **Simplicidad** | API limpia e intuitiva | Configuración frecuentemente compleja |
# | **Extensibilidad** | Integración fácil de herramientas | Dependiente del marco |
# | **Preparado para Empresas** | Diseñado para producción | Varía según el marco |
#
# ## 🚀 Primeros Pasos
#
# ¡Sigue las celdas a continuación para construir tu primer agente básico y comprender los conceptos agénticos fundamentales!

# %%
! pip install agent-framework-core  -U

# %%
# 📚 Exploring Agentic Frameworks - Basic Agent Example
# This example demonstrates core concepts of the Microsoft Agent Framework

# 📦 Import Required Libraries
import os                     # For environment variable access
from random import randint    # For generating random selections

from dotenv import load_dotenv  # For loading .env configuration files

# %%
# 🤖 Import Core Agent Framework Components
# ChatAgent: The main conversational agent class
# OpenAIChatClient: Client for connecting to OpenAI-compatible APIs
from agent_framework import Agent
from agent_framework.openai import OpenAIChatClient

# %%
# 🔧 Initialize Environment Configuration
# Load environment variables from .env file
# This enables secure storage of API keys and endpoints
load_dotenv()
# Out:
# True

# %%
# 🛠️ Tool Function: Random Destination Generator
# This demonstrates how to create tools that agents can use
# Tools extend the agent's capabilities beyond just conversation
def get_random_destination() -> str:
    """Get a random vacation destination.
    
    This function serves as a tool that the agent can call when it needs
    to suggest a random destination for travel planning.
    
    Returns:
        str: A randomly selected destination from the predefined list
    """
    # Curated list of popular vacation destinations worldwide
    destinations = [
        "Barcelona, Spain",
        "Paris, France", 
        "Berlin, Germany",
        "Tokyo, Japan",
        "Sydney, Australia",
        "New York, USA",
        "Cairo, Egypt",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # Return a randomly selected destination
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Create OpenAI Chat Client
# This demonstrates how to connect to GitHub Models (OpenAI-compatible API)
# The client handles all communication with the AI model
openai_chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # API endpoint URL
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model identifier (e.g., gpt-4o-mini)
)

# %%
# 🤖 Create the Basic Agent
# This demonstrates the core agent creation pattern in the framework
# Key components: chat client, instructions, and tools
agent = Agent(
    client=openai_chat_client,  # The AI model client for generating responses
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations.",  # System prompt defining agent behavior
    tools=[get_random_destination]   # List of available tools the agent can use
)

# %%
#thread = agent.get_new_thread()
session = agent.create_session()

# %%
#response1 = await agent.run("Plan me a day trip",thread= thread)
response1 = await agent.run("Plan me a day trip",session= session)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# How about a day trip to Barcelona, Spain? Here’s a suggested itinerary for your day:
#
# ### Morning:
# - **Breakfast at a Local Café**: Start your day with delicious pastries and coffee at a local café, such as Café de l’Opera.
# - **Visit La Sagrada Familia**: Explore Gaudí’s iconic basilica. Make sure to purchase tickets in advance to avoid long lines.
#
# ### Midday:
# - **Lunch at La Boqueria Market**: Head to Mercat de Sant Josep de la Boqueria for a vibrant food market experience. Try some local tapas or fresh seafood.
# - **Stroll down Las Ramblas**: Walk along this famous street, enjoy the street performers, and possibly stop for some shopping.
#
# ### Afternoon:
# - **Visit Park Güell**: Discover more of Gaudí’s work in this colorful park filled with unique sculptures and beautiful gardens.
# - **Explore the Gothic Quarter**: Wander through the narrow medieval streets, visit the Barcelona Cathedral, and check out the local shops.
#
# ### Evening:
# ...

# %%
response2 = await agent.run("I don't like that destination. Plan me another vacation.",session= session)

# %%
last_message = response2.messages[-1]
text_content = last_message.contents[0].text
print("Change plan:")
print(text_content)
# Out:
# Change plan:
# How about a vacation to Cairo, Egypt? Here’s a proposed itinerary for your trip:
#
# ### Day 1: Arrival in Cairo
# - **Check-in to Your Hotel**: Settle into your accommodations and freshen up.
# - **Explore the Nile River**: Enjoy a leisurely evening cruise on the Nile, with dinner included, while viewing the city skyline.
#
# ### Day 2: Ancient Wonders
# - **Visit the Pyramids of Giza**: Start your day by visiting the iconic pyramids and the Sphinx. Consider hiring a guide to learn more about the history.
# - **Explore the Solar Boat Museum**: Located near the pyramids, this museum exhibits an ancient solar barque that belonged to Pharaoh Khufu.
# - **Lunch at a Local Eatery**: Try traditional Egyptian cuisine, such as koshari or falafel.
# - **Visit the Egyptian Museum**: In the afternoon, explore the vast collection of artifacts, including treasures from King Tutankhamun's tomb.
#
# ### Day 3: Culture and History
# ...

# %% [markdown]
# ---
#
# **Descargo de responsabilidad**:
# Este documento ha sido traducido utilizando el servicio de traducción automática [Co-op Translator](https://github.com/Azure/co-op-translator). Aunque nos esforzamos por garantizar la precisión, tenga en cuenta que las traducciones automáticas pueden contener errores o imprecisiones. El documento original en su idioma nativo debe considerarse como la fuente autorizada. Para información crítica, se recomienda una traducción profesional realizada por humanos. No nos hacemos responsables de malentendidos o interpretaciones erróneas que puedan surgir del uso de esta traducción.
