# %% [markdown]
# # 🛠️ Uso Avanzado de Herramientas con Modelos de GitHub (Python)
#
# ## 📋 Objetivos de Aprendizaje
#
# Este cuaderno demuestra patrones avanzados de integración de herramientas utilizando el Marco de Agentes de Microsoft con Modelos de GitHub. Aprenderás a crear, gestionar y orquestar múltiples herramientas para construir capacidades sofisticadas en agentes.
#
# **Lo que dominarás:**
# - 🔧 **Arquitectura Multi-Herramienta**: Construcción de agentes con múltiples herramientas especializadas
# - 🎯 **Lógica de Selección de Herramientas**: Cómo los agentes eligen la herramienta adecuada para cada tarea
# - 📊 **Herramientas de Procesamiento de Datos**: Creación de herramientas que manejan diferentes tipos de datos
# - 🔗 **Composición de Herramientas**: Combinación de herramientas para flujos de trabajo complejos
#
# ## 🎯 Patrones Clave de Herramientas
#
# ### Principios de Diseño de Herramientas
# - **Responsabilidad Única**: Cada herramienta tiene un propósito claro y enfocado
# - **Seguridad de Tipos**: Tipificación fuerte para una ejecución confiable de herramientas
# - **Manejo de Errores**: Patrones de fallo y recuperación elegantes
# - **Composibilidad**: Herramientas que funcionan bien juntas
#
# ### Características Avanzadas de Herramientas
# - **Conciencia de Contexto**: Herramientas que entienden el contexto de la conversación
# - **Validación de Datos**: Sanitización de entradas y validación de salidas
# - **Optimización de Rendimiento**: Patrones eficientes de ejecución de herramientas
# - **Extensibilidad**: Adición sencilla de nuevas capacidades de herramientas
#
# ## 🔧 Arquitectura Técnica
#
# ### Componentes Principales
# - **Marco de Agentes de Microsoft**: Implementación en Python con soporte avanzado para herramientas
# - **Integración con Modelos de GitHub**: Acceso a modelos de lenguaje de alto rendimiento
# - **Sistema de Registro de Herramientas**: Gestión organizada de capacidades de agentes
# - **Patrones de Recuperación de Errores**: Manejo robusto de fallos en la ejecución de herramientas
#
# ### Flujo de Integración de Herramientas
# ```python
# User Request → Agent Analysis → Tool Selection → Tool Execution → Response Synthesis
# ```
#
# ## 🛠️ Categorías de Herramientas Demostradas
#
# ### 1. **Herramientas de Generación de Datos**
# - Generador aleatorio de destinos
# - Proveedor de información meteorológica
# - Calculadora de costos de viaje
# - Motor de recomendación de actividades
#
# ### 2. **Herramientas de Procesamiento**
# - Formateo y validación de texto
# - Utilidades de transformación de datos
# - Funciones de análisis de contenido
# - Herramientas de mejora de respuestas
#
# ### 3. **Herramientas de Integración**
# - Conectores de API externas
# - Operaciones en el sistema de archivos
# - Interfaces de consulta de bases de datos
# - Utilidades de scraping web
#
# ## ⚙️ Requisitos Previos y Configuración
#
# **Dependencias Requeridas:**
# ```bash
#
# pip install agent-framework-core -U
# ```
#
# **Configuración del Entorno (archivo .env):**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# **APIs Opcionales:**
# - Clave de API de servicio meteorológico (para herramientas de clima)
# - Acceso a API de conversión de moneda
# - Credenciales de servicio de información de viajes
#
# ## 🎨 Patrones de Diseño
#
# ### Patrón de Fábrica de Herramientas
# - Creación y configuración centralizada de herramientas
# - Diseño consistente de interfaces de herramientas
# - Registro y descubrimiento sencillo de herramientas
#
# ### Patrón de Comando
# - Lógica encapsulada de ejecución de herramientas
# - Funcionalidad de deshacer/rehacer para operaciones complejas
# - Registro de auditoría para el uso de herramientas
#
# ### Patrón de Observador
# - Monitoreo de ejecución de herramientas
# - Recopilación de métricas de rendimiento
# - Reporte de errores y alertas
#
# ## 🚀 Mejores Prácticas
#
# - **Documentación de Herramientas**: Descripciones claras para la comprensión del agente
# - **Validación de Entradas**: Comprobación robusta de parámetros y sanitización
# - **Formateo de Salidas**: Respuestas consistentes y analizables de las herramientas
# - **Mensajes de Error**: Información útil de errores para depuración
# - **Rendimiento**: Ejecución optimizada de herramientas para mayor capacidad de respuesta
#
# ¿Listo para construir agentes con capacidades poderosas de herramientas? ¡Vamos a crear algo increíble! ⚡

# %%
! pip install agent-framework-core -U
# Out:
# Requirement already satisfied: agent-framework-core in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (1.0.0rc2)
# Requirement already satisfied: typing-extensions in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (1.2.2)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (0.4.15)
# Requirement already satisfied: openai>=1.99.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (2.24.0)
# Requirement already satisfied: azure-identity<2,>=1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (1.25.2)
# Requirement already satisfied: azure-ai-projects==2.0.0b3 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (2.0.0b3)
# Requirement already satisfied: mcp<2,>=1.24.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (1.26.0)
# Requirement already satisfied: packaging>=24.1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from agent-framework-core) (26.0)
# Requirement already satisfied: isodate>=0.6.1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from azure-ai-projects==2.0.0b3->agent-framework-core) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from azure-ai-projects==2.0.0b3->agent-framework-core) (1.38.2)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from azure-ai-projects==2.0.0b3->agent-framework-core) (12.28.0)
# Requirement already satisfied: cryptography>=2.5 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.35.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from azure-identity<2,>=1->agent-framework-core) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.0.22)
# Requirement already satisfied: pywin32>=310 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.3.2)
# Requirement already satisfied: starlette>=0.27 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.41.0)
# Requirement already satisfied: websockets>=15.0.1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core) (16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from pydantic<3,>=2->agent-framework-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from pydantic<3,>=2->agent-framework-core) (2.41.5)
# Requirement already satisfied: idna>=2.8 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from anyio>=4.5->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (3.11)
# Requirement already satisfied: requests>=2.21.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b3->agent-framework-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (2.0.0)
# Requirement already satisfied: pycparser in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core) (3.0)
# Requirement already satisfied: certifi in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b3->agent-framework-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b3->agent-framework-core) (2.6.3)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from openai>=1.99.0->agent-framework-core) (0.13.0)
# Requirement already satisfied: sniffio in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from openai>=1.99.0->agent-framework-core) (1.3.1)
# Requirement already satisfied: tqdm>4 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from openai>=1.99.0->agent-framework-core) (4.67.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from opentelemetry-api>=1.39.0->agent-framework-core) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core) (0.60b1)
# Requirement already satisfied: colorama in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core) (0.4.6)
# Requirement already satisfied: click>=7.0 in C:\proyectos_ia\ai-agents-for-beginners\.venv\Lib\site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core) (8.3.1)

# %%
# � Import core dependencies for Agent Framework and tool integration
# This sets up the essential libraries for building intelligent agents with tool capabilities

import asyncio
import os
import json

from dotenv import load_dotenv  # For loading environment variables securely
from random import randint

# These are the core components for building tool-enabled agents
from agent_framework import Agent           # Main agent class
from agent_framework.openai import OpenAIChatClient  # OpenAI-compatible client

# %%
load_dotenv()
# Out:
# True

# %%
# 🔑 Environment variables verification
# Ensure all required GitHub Models credentials are properly configured
print("GITHUB_ENDPOINT:", os.environ.get("GITHUB_ENDPOINT"))
print("GITHUB_TOKEN:", "***" if os.environ.get("GITHUB_TOKEN") else "Not set")
print("GITHUB_MODEL_ID:", os.environ.get("GITHUB_MODEL_ID"))
# Out:
# GITHUB_ENDPOINT: https://models.inference.ai.azure.com
# GITHUB_TOKEN: ***
# GITHUB_MODEL_ID: gpt-4o-mini

# %%
# 🧪 Test GitHub Models connectivity
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
# 🛠️ Define travel planning tools for agent integration
# These functions provide specific capabilities that the agent can invoke dynamically

def get_random_destination() -> str:
    """
    🎲 Random destination generator tool
    Returns a randomly selected travel destination from curated list
    Useful when customers need inspiration for their next vacation
    """
    destinations = [
        "Paris, France",
        "Tokyo, Japan", 
        "New York City, USA",
        "London, England",
        "Rome, Italy",
        "Sydney, Australia",
        "Dubai, UAE",
        "Barcelona, Spain",
        "Bangkok, Thailand",
        "Amsterdam, Netherlands",
        "Istanbul, Turkey",
        "Prague, Czech Republic",
        "Santorini, Greece",
        "Reykjavik, Iceland",
        "Marrakech, Morocco",
        "Cape Town, South Africa",
        "Rio de Janeiro, Brazil",
        "Bali, Indonesia"
    ]
    # 🎯 Return random selection from the curated destination list
    return destinations[randint(0, len(destinations) - 1)]

# %%
# 🔗 Initialize GitHub Models chat client for agent communication
# Creates the primary interface between the agent and the language model
openai_chat_client = OpenAIChatClient(base_url=os.environ.get("GITHUB_ENDPOINT"), api_key=os.environ.get("GITHUB_TOKEN"), model_id=os.environ.get("GITHUB_MODEL_ID"))

# %%
# 🤖 Configure travel agent identity and behavioral instructions
# Define the agent's personality, capabilities, and operational guidelines

AGENT_NAME = "TravelAgent"

AGENT_INSTRUCTIONS = """You are a helpful AI Agent that can help plan vacations for customers at random destinations
"""

# %%
agent = Agent(
        name = AGENT_NAME,
        client=openai_chat_client,
        instructions=AGENT_INSTRUCTIONS,
        tools=[get_random_destination]
)

# %%
#thread = agent.get_new_thread()
session = agent.create_session()

# %%
#response1 = await agent.run("Plan me a day trip",thread= thread)
response1 = await agent.run("Plan me a day trip",session= session)

# %%
last_message = response1.messages[-1]
text_content = last_message.contents[0].text
print("Travel plan:")
print(text_content)
# Out:
# Travel plan:
# I have selected London, England as your destination for a day trip! Here’s a suggested itinerary for your day:
#
# ### Morning
# - **Breakfast at a Local Café**: Start your day with a traditional English breakfast at a local café. Try dishes like scrambled eggs, sausages, baked beans, and toast.
#
# - **Visit the British Museum**: After breakfast, head to the British Museum. It's free to enter and home to a vast collection of art and antiquities from around the world, including the Rosetta Stone and the Elgin Marbles.
#
# ### Afternoon
# - **Lunch at Borough Market**: Make your way to Borough Market for lunch. This bustling food market offers a variety of street food, fresh produce, and gourmet delights.
#
# - **Explore the Southbank**: After lunch, take a stroll along the Southbank of the River Thames. Enjoy views of iconic landmarks such as the Tower Bridge and the Shard. You can also visit the Tate Modern if you're interested in contemporary art.
#
# ### Evening
# - **Dinner in Covent Garden**: Head to Covent Garden for a delightful dinner. There are numerous restaurants and eateries to choose from, offering everything from British cuisine to international dishes.
#
# - **Catch a Show in the West End**: End your day with a spectacular show in London’s West End. Check out what's playing and book your tickets in advance for a popular musical or play.
#
# ### Tips
# - Wear comfortable shoes as you’ll be doing quite a bit of walking.
# - Consider using the London Underground (Tube) for efficient travel around the city.
# - Keep an umbrella handy, as London weather can be unpredictable!
#
# Enjoy your day trip! If you need further assistance or adjustments to your itinerary, just let me know!

# %% [markdown]
# ---
#
# **Descargo de responsabilidad**:
# Este documento ha sido traducido utilizando el servicio de traducción automática [Co-op Translator](https://github.com/Azure/co-op-translator). Aunque nos esforzamos por garantizar la precisión, tenga en cuenta que las traducciones automatizadas pueden contener errores o imprecisiones. El documento original en su idioma nativo debe considerarse como la fuente autorizada. Para información crítica, se recomienda una traducción profesional realizada por humanos. No nos hacemos responsables de malentendidos o interpretaciones erróneas que puedan surgir del uso de esta traducción.
